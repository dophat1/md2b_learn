# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("housing_prices.csv")
df_train, df_test = train_test_split(df, test_size=0.2)
X_train = df_train[['Sqrm']]
y_train = df_train['Price']

X_test = df_test[['Sqrm']]
y_test = df_test['Price']

# %%
plt.scatter(X_train, y_train, color='deeppink')
plt.scatter(X_test, y_test, color='blue')
plt.xlabel("Square meter")
plt.ylabel("Price")
plt.legend(["Train", "Test"])

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test, y_pred
# Out:
# (39    225000
#  15    239000
#  7     181000
#  41    443000
#  38    406000
#  23    256000
#  6     228000
#  12    165000
#  36    305000
#  46    254000
#  Name: Price, dtype: int64,
#  array([206953.26036603, 242263.9095353 , 171642.61119677, 449083.42609814,
#         363328.99240135, 267485.80179906, 247308.28798805, 181731.36810227,
#         328018.34323209, 262441.42334631]))

# %%
y_pred = model.predict(X_test)

# %%
sum((y_pred - y_test)**2)
# Out:
# 3667495664.4933867

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 5178.122255947732
# [5044.37845275]
